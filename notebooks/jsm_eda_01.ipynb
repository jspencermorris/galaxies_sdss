# %%
# import libraries

import pandas as pd
import numpy as np

# %%
# set display settings

pd.set_option("display.max_rows", None)
pd.set_option('display.max_columns', None)

# %%
# specify columns, datatypes, and load full consolidated sdss dataset

# load column names from file into a list
sdss_headers = pd.read_csv('../data/processed/sdss_full.csv.gz', compression='gzip', header=0, index_col=0, nrows=0).columns.tolist()

# specify groups of columns
object_identifiers = ['dr7objid', 'dr8objid', 'specobjid', 'gz2_filenumber']
object_locations = ['ra', 'dec']
object_class_labels = ['sdss_clean_class_name', 'sdss_clean_subclass_name', 'gz2_subclass_name', 'elodie_spectral_type']
object_binary_labels = [label for label in sdss_headers if 'flag' in label]
object_filters = ['score', 'petroR90_r']
object_features = ['redshift_final', 'redshift_noqso', 'redshift_elodie',
                   'u_s', 'g_s', 'r_s', 'i_s', 'z_s',
                   'u_p', 'g_p', 'r_p', 'i_p', 'z_p',
                   'elodie_color_index', 'elodie_temperature', 'elodie_metallicity']

# create a datatype dictionary for object_identifiers
object_dtypes = {col: 'string' for col in object_identifiers}

# load full consolidated sdss dataset
sdss_full = pd.read_csv('../data/processed/sdss_full.csv.gz', compression='gzip', header=0, dtype=object_dtypes)
# Out:
# "object_dtypes.update({col: 'float64' for col in object_locations})\nobject_dtypes.update({col: 'string' for col in object_class_labels})\nobject_dtypes.update({col: 'string' for col in object_binary_labels}) # <------------------------------------ need to figure out how to load the bools (investigate display below)\nobject_dtypes.update({col: 'float64' for col in object_filters})\nobject_dtypes.update({col: 'float64' for col in object_features})"

# %%
# inspect the imported data
 
 # display some data
display(sdss_full.head(3))
display(sdss_full.tail(3))
display(sdss_full.sample(10))
 
# inspect dataframe
print(sdss_full.shape)
print(sdss_full.info())
for identifier in object_identifiers:
    print(f"\nTop Value Counts:  {sdss_full[identifier].value_counts().nlargest(5)}")
# Out:
#              dr7objid             dr8objid           specobjid gz2_filenumber  \
# 0  588007006336254064  1237651252584448100  693716010653476864         192933
# 1  588007006336254083  1237651252584448112  693718759432546304           <NA>
# 2  587729226614112406  1237651252584251555  693718209676732416          32264
#
#            ra        dec sdss_clean_class_name sdss_clean_subclass_name  \
# 0  236.355530  54.820911                galaxy              STARFORMING
# 1  236.342000  54.802830                galaxy                      NaN
# 2  235.891464  55.133472                galaxy                      AGN
#
#   gz2_subclass_name elodie_spectral_type gz1_flag_spiral gz1_flag_elliptical  \
# 0             SBc2l                  NaN            True               False
# 1               NaN                  NaN           False               False
# 2             SBc?t                  NaN            True               False
#
#   gz1_flag_uncertain gz2_flag_smooth gz2_flag_features_or_disk  \
# 0              False           False                      True
# 1               True             NaN                       NaN
# 2              False           False                      True
#
#   gz2_flag_star_or_artifact gz2_flag_edgeon_yes gz2_flag_edgeon_no  \
# 0                     False               False               True
# 1                       NaN                 NaN                NaN
# 2                     False               False               True
#
#   gz2_flag_bar_yes gz2_flag_bar_no gz2_flag_spiral_yes gz2_flag_spiral_no  \
# 0             True           False                True              False
# 1              NaN             NaN                 NaN                NaN
# 2            False           False                True              False
#
#   gz2_flag_bulge_none1 gz2_flag_bulge_small gz2_flag_bulge_medium  \
# 0                False                False                 False
# 1                  NaN                  NaN                   NaN
# 2                False                False                 False
#
#   gz2_flag_bulge_large gz2_flag_odd_yes gz2_flag_odd_no  \
# 0                False            False           False
# 1                  NaN              NaN             NaN
# 2                False            False           False
#
#   gz2_flag_round_circular gz2_flag_round_medium gz2_flag_round_cigar  \
# 0                   False                 False                False
# 1                     NaN                   NaN                  NaN
# 2                   False                 False                False
#
#   gz2_flag_feature_ring gz2_flag_feature_lens_or_arc  \
# 0                 False                        False
# 1                   NaN                          NaN
# 2                 False                        False
#
#   gz2_flag_feature_disturbed gz2_flag_feature_irregular  \
# 0                      False                      False
# 1                        NaN                        NaN
# 2                      False                      False
#
#   gz2_flag_feature_other gz2_flag_feature_merger gz2_flag_feature_dust_lane  \
# 0                  False                   False                      False
# 1                    NaN                     NaN                        NaN
# 2                  False                   False                      False
#
#   gz2_flag_bulge_round gz2_flag_bulge_boxy gz2_flag_bulge_none2  \
# 0                 True               False                False
# 1                  NaN                 NaN                  NaN
# 2                False               False                False
#
#   gz2_flag_arms_tight gz2_flag_arms_medium gz2_flag_arms_loose  \
# 0               False                False               False
# 1                 NaN                  NaN                 NaN
# 2               False                False               False
#
#   gz2_flag_arms_1 gz2_flag_arms_2 gz2_flag_arms_3 gz2_flag_arms_4  \
# 0           False           False           False           False
# 1             NaN             NaN             NaN             NaN
# 2           False           False           False           False
#
#   gz2_flag_arms_many gz2_flag_arms_unsure     score  petroR90_r  \
# 0              False                False  0.850861   10.064850
# 1                NaN                  NaN  0.850861    6.995347
# 2              False                False  0.863360   10.959250
#
#    redshift_final  redshift_noqso  redshift_elodie        u_s       g_s  \
# 0        0.080127             0.0              0.0   6.013997  19.66714
# 1        0.193371             0.0              0.0   4.234163  11.95987
# 2        0.040399             0.0              0.0  18.203950  60.73151
#
#          r_s        i_s        z_s       u_p       g_p       r_p       i_p  \
# 0   43.23034   61.21994   73.57887  18.91253  17.53665  16.81467  16.43992
# 1   31.28475   46.43085   56.40972  19.66911  18.16584  17.27259  16.84296
# 2  129.97640  179.21480  215.18610  17.46699  15.83618  15.09113  14.70903
#
#         z_p  elodie_color_index  elodie_temperature  elodie_metallicity
# 0  16.18453                 NaN                 NaN                 NaN
# 1  16.55850                 NaN                 NaN                 NaN
# 2  14.41906                 NaN                 NaN                 NaN
#         dr7objid             dr8objid            specobjid gz2_filenumber  \
# 1654165     <NA>  1237658613593997533  9259471051523641344           <NA>
# 1654166     <NA>  1237658613594063054  9259459231773642752           <NA>
# 1654167     <NA>  1237658613594063058  9259460331285270528           <NA>
#
#                 ra        dec sdss_clean_class_name sdss_clean_subclass_name  \
# 1654165  177.50007  50.211641                quasar                      NaN
# 1654166  177.79391  50.208232          unclassified             unclassified
# 1654167  177.79678  50.375821                quasar                BROADLINE
#
#         gz2_subclass_name elodie_spectral_type gz1_flag_spiral  \
# 1654165               NaN                  NaN             NaN
# 1654166               NaN                  NaN             NaN
# 1654167               NaN                  NaN             NaN
#
#         gz1_flag_elliptical gz1_flag_uncertain gz2_flag_smooth  \
# 1654165                 NaN                NaN             NaN
# 1654166                 NaN                NaN             NaN
# 1654167                 NaN                NaN             NaN
#
#         gz2_flag_features_or_disk gz2_flag_star_or_artifact  \
# 1654165                       NaN                       NaN
# 1654166                       NaN                       NaN
# 1654167                       NaN                       NaN
#
#         gz2_flag_edgeon_yes gz2_flag_edgeon_no gz2_flag_bar_yes  \
# 1654165                 NaN                NaN              NaN
# 1654166                 NaN                NaN              NaN
# 1654167                 NaN                NaN              NaN
#
#         gz2_flag_bar_no gz2_flag_spiral_yes gz2_flag_spiral_no  \
# 1654165             NaN                 NaN                NaN
# 1654166             NaN                 NaN                NaN
# 1654167             NaN                 NaN                NaN
#
#         gz2_flag_bulge_none1 gz2_flag_bulge_small gz2_flag_bulge_medium  \
# 1654165                  NaN                  NaN                   NaN
# 1654166                  NaN                  NaN                   NaN
# 1654167                  NaN                  NaN                   NaN
#
#         gz2_flag_bulge_large gz2_flag_odd_yes gz2_flag_odd_no  \
# 1654165                  NaN              NaN             NaN
# 1654166                  NaN              NaN             NaN
# 1654167                  NaN              NaN             NaN
#
#         gz2_flag_round_circular gz2_flag_round_medium gz2_flag_round_cigar  \
# 1654165                     NaN                   NaN                  NaN
# 1654166                     NaN                   NaN                  NaN
# 1654167                     NaN                   NaN                  NaN
#
#         gz2_flag_feature_ring gz2_flag_feature_lens_or_arc  \
# 1654165                   NaN                          NaN
# 1654166                   NaN                          NaN
# 1654167                   NaN                          NaN
#
#         gz2_flag_feature_disturbed gz2_flag_feature_irregular  \
# 1654165                        NaN                        NaN
# 1654166                        NaN                        NaN
# 1654167                        NaN                        NaN
#
#         gz2_flag_feature_other gz2_flag_feature_merger  \
# 1654165                    NaN                     NaN
# 1654166                    NaN                     NaN
# 1654167                    NaN                     NaN
#
#         gz2_flag_feature_dust_lane gz2_flag_bulge_round gz2_flag_bulge_boxy  \
# 1654165                        NaN                  NaN                 NaN
# 1654166                        NaN                  NaN                 NaN
# 1654167                        NaN                  NaN                 NaN
#
#         gz2_flag_bulge_none2 gz2_flag_arms_tight gz2_flag_arms_medium  \
# 1654165                  NaN                 NaN                  NaN
# 1654166                  NaN                 NaN                  NaN
# 1654167                  NaN                 NaN                  NaN
#
#         gz2_flag_arms_loose gz2_flag_arms_1 gz2_flag_arms_2 gz2_flag_arms_3  \
# 1654165                 NaN             NaN             NaN             NaN
# 1654166                 NaN             NaN             NaN             NaN
# 1654167                 NaN             NaN             NaN             NaN
#
#         gz2_flag_arms_4 gz2_flag_arms_many gz2_flag_arms_unsure     score  \
# 1654165             NaN                NaN                  NaN  0.807279
# 1654166             NaN                NaN                  NaN  0.819832
# 1654167             NaN                NaN                  NaN  0.819832
#
#          petroR90_r  redshift_final  redshift_noqso  redshift_elodie  \
# 1654165         NaN        1.076416        0.231599              0.0
# 1654166         NaN        2.060357       -0.004214              0.0
# 1654167         NaN        1.856644        0.123349              0.0
#
#               u_s       g_s       r_s       i_s       z_s       u_p       g_p  \
# 1654165  0.765539  1.052253  1.874948  1.917074  2.357079  21.84895  21.91097
# 1654166  7.819283  5.829438  6.240019  6.629135  8.703038  20.83662  20.68300
# 1654167  0.191132  1.780057  1.906872  2.832188  3.034446  22.02470  21.56175
#
#               r_p       i_p       z_p  elodie_color_index  elodie_temperature  \
# 1654165  21.59686  21.60826  21.09701                 0.0                 0.0
# 1654166  20.50494  20.39749  20.39611                 0.0                 0.0
# 1654167  21.59132  21.17899  21.09313                 0.0                 0.0
#
#          elodie_metallicity
# 1654165                 0.0
# 1654166                 0.0
# 1654167                 0.0
#                    dr7objid             dr8objid            specobjid  \
# 1214764                <NA>  1237667912198718139  2815982388159473664
# 153783   588009368009834500  1237653614258028686   622731533672802304
# 152333   587722984443871470  1237655467523440817   348072698833823744
# 377055   587735235807740227  1237661088028819723  1424315654340634624
# 1304280                <NA>  1237648705652850793  3259573215663515648
# 494758   587742062168965497  1237667783393870210  2838473730756208640
# 486122   587735349086192101  1237671123219186141  1978318613110614016
# 1292787                <NA>  1237666407919649033  1208176131514066944
# 1294573                <NA>  1237651252022411704  8221370715431260160
# 1399643                <NA>  1237651496297759358  4159246966596063232
#
#         gz2_filenumber          ra        dec sdss_clean_class_name  \
# 1214764           <NA>  172.096660  24.929282                quasar
# 153783            <NA>  137.326900  53.280030                galaxy
# 152333            <NA>  224.411800   0.872972          unclassified
# 377055            <NA>  121.174900  23.207030                galaxy
# 1304280           <NA>  187.996170   0.873443                  star
# 494758            <NA>  238.235900  14.405420                galaxy
# 486122          255044  124.951157   8.153255                galaxy
# 1292787           <NA>   32.287647  -0.051418                  star
# 1294573           <NA>  129.621320  51.721043                  star
# 1399643           <NA>  125.502400  51.406144                quasar
#
#         sdss_clean_subclass_name gz2_subclass_name elodie_spectral_type  \
# 1214764                      NaN               NaN                  NaN
# 153783               STARFORMING               NaN                  NaN
# 152333              unclassified               NaN                  NaN
# 377055                       NaN               NaN                  NaN
# 1304280                       G2               NaN                   F8
# 494758               STARFORMING               NaN                  NaN
# 486122               STARFORMING                Ec                  NaN
# 1292787                       M1               NaN               M2Vvar
# 1294573           F3/F5V (30743)               NaN                  M1V
# 1399643                BROADLINE               NaN                  NaN
#
#         gz1_flag_spiral gz1_flag_elliptical gz1_flag_uncertain  \
# 1214764             NaN                 NaN                NaN
# 153783            False               False               True
# 152333             True               False              False
# 377055            False               False               True
# 1304280             NaN                 NaN                NaN
# 494758            False               False               True
# 486122             True               False              False
# 1292787             NaN                 NaN                NaN
# 1294573             NaN                 NaN                NaN
# 1399643             NaN                 NaN                NaN
#
#         gz2_flag_smooth gz2_flag_features_or_disk gz2_flag_star_or_artifact  \
# 1214764             NaN                       NaN                       NaN
# 153783              NaN                       NaN                       NaN
# 152333              NaN                       NaN                       NaN
# 377055              NaN                       NaN                       NaN
# 1304280             NaN                       NaN                       NaN
# 494758              NaN                       NaN                       NaN
# 486122             True                     False                     False
# 1292787             NaN                       NaN                       NaN
# 1294573             NaN                       NaN                       NaN
# 1399643             NaN                       NaN                       NaN
#
#         gz2_flag_edgeon_yes gz2_flag_edgeon_no gz2_flag_bar_yes  \
# 1214764                 NaN                NaN              NaN
# 153783                  NaN                NaN              NaN
# 152333                  NaN                NaN              NaN
# 377055                  NaN                NaN              NaN
# 1304280                 NaN                NaN              NaN
# 494758                  NaN                NaN              NaN
# 486122                False              False            False
# 1292787                 NaN                NaN              NaN
# 1294573                 NaN                NaN              NaN
# 1399643                 NaN                NaN              NaN
#
#         gz2_flag_bar_no gz2_flag_spiral_yes gz2_flag_spiral_no  \
# 1214764             NaN                 NaN                NaN
# 153783              NaN                 NaN                NaN
# 152333              NaN                 NaN                NaN
# 377055              NaN                 NaN                NaN
# 1304280             NaN                 NaN                NaN
# 494758              NaN                 NaN                NaN
# 486122             True                True              False
# 1292787             NaN                 NaN                NaN
# 1294573             NaN                 NaN                NaN
# 1399643             NaN                 NaN                NaN
#
#         gz2_flag_bulge_none1 gz2_flag_bulge_small gz2_flag_bulge_medium  \
# 1214764                  NaN                  NaN                   NaN
# 153783                   NaN                  NaN                   NaN
# 152333                   NaN                  NaN                   NaN
# 377055                   NaN                  NaN                   NaN
# 1304280                  NaN                  NaN                   NaN
# 494758                   NaN                  NaN                   NaN
# 486122                  True                False                 False
# 1292787                  NaN                  NaN                   NaN
# 1294573                  NaN                  NaN                   NaN
# 1399643                  NaN                  NaN                   NaN
#
#         gz2_flag_bulge_large gz2_flag_odd_yes gz2_flag_odd_no  \
# 1214764                  NaN              NaN             NaN
# 153783                   NaN              NaN             NaN
# 152333                   NaN              NaN             NaN
# 377055                   NaN              NaN             NaN
# 1304280                  NaN              NaN             NaN
# 494758                   NaN              NaN             NaN
# 486122                 False            False            True
# 1292787                  NaN              NaN             NaN
# 1294573                  NaN              NaN             NaN
# 1399643                  NaN              NaN             NaN
#
#         gz2_flag_round_circular gz2_flag_round_medium gz2_flag_round_cigar  \
# 1214764                     NaN                   NaN                  NaN
# 153783                      NaN                   NaN                  NaN
# 152333                      NaN                   NaN                  NaN
# 377055                      NaN                   NaN                  NaN
# 1304280                     NaN                   NaN                  NaN
# 494758                      NaN                   NaN                  NaN
# 486122                    False                 False                 True
# 1292787                     NaN                   NaN                  NaN
# 1294573                     NaN                   NaN                  NaN
# 1399643                     NaN                   NaN                  NaN
#
#         gz2_flag_feature_ring gz2_flag_feature_lens_or_arc  \
# 1214764                   NaN                          NaN
# 153783                    NaN                          NaN
# 152333                    NaN                          NaN
# 377055                    NaN                          NaN
# 1304280                   NaN                          NaN
# 494758                    NaN                          NaN
# 486122                  False                        False
# 1292787                   NaN                          NaN
# 1294573                   NaN                          NaN
# 1399643                   NaN                          NaN
#
#         gz2_flag_feature_disturbed gz2_flag_feature_irregular  \
# 1214764                        NaN                        NaN
# 153783                         NaN                        NaN
# 152333                         NaN                        NaN
# 377055                         NaN                        NaN
# 1304280                        NaN                        NaN
# 494758                         NaN                        NaN
# 486122                       False                      False
# 1292787                        NaN                        NaN
# 1294573                        NaN                        NaN
# 1399643                        NaN                        NaN
#
#         gz2_flag_feature_other gz2_flag_feature_merger  \
# 1214764                    NaN                     NaN
# 153783                     NaN                     NaN
# 152333                     NaN                     NaN
# 377055                     NaN                     NaN
# 1304280                    NaN                     NaN
# 494758                     NaN                     NaN
# 486122                   False                   False
# 1292787                    NaN                     NaN
# 1294573                    NaN                     NaN
# 1399643                    NaN                     NaN
#
#         gz2_flag_feature_dust_lane gz2_flag_bulge_round gz2_flag_bulge_boxy  \
# 1214764                        NaN                  NaN                 NaN
# 153783                         NaN                  NaN                 NaN
# 152333                         NaN                  NaN                 NaN
# 377055                         NaN                  NaN                 NaN
# 1304280                        NaN                  NaN                 NaN
# 494758                         NaN                  NaN                 NaN
# 486122                        True                False               False
# 1292787                        NaN                  NaN                 NaN
# 1294573                        NaN                  NaN                 NaN
# 1399643                        NaN                  NaN                 NaN
#
#         gz2_flag_bulge_none2 gz2_flag_arms_tight gz2_flag_arms_medium  \
# 1214764                  NaN                 NaN                  NaN
# 153783                   NaN                 NaN                  NaN
# 152333                   NaN                 NaN                  NaN
# 377055                   NaN                 NaN                  NaN
# 1304280                  NaN                 NaN                  NaN
# 494758                   NaN                 NaN                  NaN
# 486122                  True                True                False
# 1292787                  NaN                 NaN                  NaN
# 1294573                  NaN                 NaN                  NaN
# 1399643                  NaN                 NaN                  NaN
#
#         gz2_flag_arms_loose gz2_flag_arms_1 gz2_flag_arms_2 gz2_flag_arms_3  \
# 1214764                 NaN             NaN             NaN             NaN
# 153783                  NaN             NaN             NaN             NaN
# 152333                  NaN             NaN             NaN             NaN
# 377055                  NaN             NaN             NaN             NaN
# 1304280                 NaN             NaN             NaN             NaN
# 494758                  NaN             NaN             NaN             NaN
# 486122                False           False           False           False
# 1292787                 NaN             NaN             NaN             NaN
# 1294573                 NaN             NaN             NaN             NaN
# 1399643                 NaN             NaN             NaN             NaN
#
#         gz2_flag_arms_4 gz2_flag_arms_many gz2_flag_arms_unsure     score  \
# 1214764             NaN                NaN                  NaN  0.876677
# 153783              NaN                NaN                  NaN  0.832386
# 152333              NaN                NaN                  NaN  0.886849
# 377055              NaN                NaN                  NaN  0.879096
# 1304280             NaN                NaN                  NaN  0.801435
# 494758              NaN                NaN                  NaN  0.883602
# 486122            False              False                 True  0.942848
# 1292787             NaN                NaN                  NaN  0.922338
# 1294573             NaN                NaN                  NaN  0.853567
# 1399643             NaN                NaN                  NaN  0.775620
#
#          petroR90_r  redshift_final  redshift_noqso  redshift_elodie  \
# 1214764         NaN        3.195375         0.00000         0.000000
# 153783     3.529115        0.100046         0.00000         0.000000
# 152333     4.802246        0.096834         0.00000         0.000000
# 377055     4.797465        0.180899         0.00000         0.000000
# 1304280         NaN        0.000397         0.00000         0.000415
# 494758     4.185265        0.149265         0.00000         0.000000
# 486122     6.156392        0.046154         0.00000         0.000000
# 1292787         NaN       -0.000100         0.00000        -0.000058
# 1294573         NaN        0.000170         0.00017         0.000000
# 1399643         NaN        0.720685         0.72087         0.000000
#
#                u_s        g_s         r_s         i_s         z_s       u_p  \
# 1214764   0.131682   1.561267    6.967295   11.866960   18.098660  23.45998
# 153783   29.654090  58.273940  101.645400  151.075600  177.566200  18.57788
# 152333    6.027494  15.598360   35.668040   54.183170   69.241000  19.68049
# 377055    3.676123  12.368020   39.751550   61.686890   82.689250  20.76941
# 1304280  28.462260  59.252390   90.751260  103.680700  113.035700  19.12071
# 494758    8.900145  23.169440   51.366430   75.071170   93.312810  19.73616
# 486122   14.585730  34.568610   72.858760  111.138100  141.014400  18.61777
# 1292787   0.101099   2.791651   12.254120   26.212550   36.494570  23.56246
# 1294573   4.223725   9.048829   14.821790   17.904590   19.571190  21.03679
# 1399643   0.262655   0.822673    1.866184    3.775192    7.029656  24.41074
#
#               g_p       r_p       i_p       z_p  elodie_color_index  \
# 1214764  21.41952  20.11442  19.95722  19.62216               0.000
# 153783   17.54083  16.98152  16.52810  16.32348                 NaN
# 152333   18.33228  17.55601  17.14058  16.83957                 NaN
# 377055   18.89691  17.67373  17.17623  16.85844                 NaN
# 1304280  17.98461  17.58187  17.45570  17.36900               0.530
# 494758   18.39584  17.54081  17.09195  16.79180                 NaN
# 486122   17.19462  16.46165  16.04338  15.71882                 NaN
# 1292787  21.40031  19.82408  18.92991  18.46614               1.491
# 1294573  20.16630  19.85361  19.73291  19.68928               1.474
# 1399643  22.84772  21.47988  20.76151  20.23670               0.000
#
#          elodie_temperature  elodie_metallicity
# 1214764                 0.0                0.00
# 153783                  NaN                 NaN
# 152333                  NaN                 NaN
# 377055                  NaN                 NaN
# 1304280              5873.0               -0.45
# 494758                  NaN                 NaN
# 486122                  NaN                 NaN
# 1292787              3980.0               -0.04
# 1294573              3705.0                0.60
# 1399643                 0.0                0.00
# (1654168, 68)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1654168 entries, 0 to 1654167
# Data columns (total 68 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   dr7objid                      658334 non-null   string
#  1   dr8objid                      1654168 non-null  string
#  2   specobjid                     1654168 non-null  string
#  3   gz2_filenumber                236466 non-null   string
#  4   ra                            1654168 non-null  float64
#  5   dec                           1654168 non-null  float64
#  6   sdss_clean_class_name         1654168 non-null  object
#  7   sdss_clean_subclass_name      1274218 non-null  object
#  8   gz2_subclass_name             236466 non-null   object
#  9   elodie_spectral_type          568139 non-null   object
#  10  gz1_flag_spiral               658334 non-null   object
#  11  gz1_flag_elliptical           658334 non-null   object
#  12  gz1_flag_uncertain            658334 non-null   object
#  13  gz2_flag_smooth               236466 non-null   object
#  14  gz2_flag_features_or_disk     236466 non-null   object
#  15  gz2_flag_star_or_artifact     236466 non-null   object
#  16  gz2_flag_edgeon_yes           236466 non-null   object
#  17  gz2_flag_edgeon_no            236466 non-null   object
#  18  gz2_flag_bar_yes              236466 non-null   object
#  19  gz2_flag_bar_no               236466 non-null   object
#  20  gz2_flag_spiral_yes           236466 non-null   object
#  21  gz2_flag_spiral_no            236466 non-null   object
#  22  gz2_flag_bulge_none1          236466 non-null   object
#  23  gz2_flag_bulge_small          236466 non-null   object
#  24  gz2_flag_bulge_medium         236466 non-null   object
#  25  gz2_flag_bulge_large          236466 non-null   object
#  26  gz2_flag_odd_yes              236466 non-null   object
#  27  gz2_flag_odd_no               236466 non-null   object
#  28  gz2_flag_round_circular       236466 non-null   object
#  29  gz2_flag_round_medium         236466 non-null   object
#  30  gz2_flag_round_cigar          236466 non-null   object
#  31  gz2_flag_feature_ring         236466 non-null   object
#  32  gz2_flag_feature_lens_or_arc  236466 non-null   object
#  33  gz2_flag_feature_disturbed    236466 non-null   object
#  34  gz2_flag_feature_irregular    236466 non-null   object
#  35  gz2_flag_feature_other        236466 non-null   object
#  36  gz2_flag_feature_merger       236466 non-null   object
#  37  gz2_flag_feature_dust_lane    236466 non-null   object
#  38  gz2_flag_bulge_round          236466 non-null   object
#  39  gz2_flag_bulge_boxy           236466 non-null   object
#  40  gz2_flag_bulge_none2          236466 non-null   object
#  41  gz2_flag_arms_tight           236466 non-null   object
#  42  gz2_flag_arms_medium          236466 non-null   object
#  43  gz2_flag_arms_loose           236466 non-null   object
#  44  gz2_flag_arms_1               236466 non-null   object
#  45  gz2_flag_arms_2               236466 non-null   object
#  46  gz2_flag_arms_3               236466 non-null   object
#  47  gz2_flag_arms_4               236466 non-null   object
#  48  gz2_flag_arms_many            236466 non-null   object
#  49  gz2_flag_arms_unsure          236466 non-null   object
#  50  score                         1654168 non-null  float64
#  51  petroR90_r                    658334 non-null   float64
#  52  redshift_final                1654168 non-null  float64
#  53  redshift_noqso                1654168 non-null  float64
#  54  redshift_elodie               1654168 non-null  float64
#  55  u_s                           1654168 non-null  float64
#  56  g_s                           1654168 non-null  float64
#  57  r_s                           1654168 non-null  float64
#  58  i_s                           1654168 non-null  float64
#  59  z_s                           1654168 non-null  float64
#  60  u_p                           1654168 non-null  float64
#  61  g_p                           1654168 non-null  float64
#  62  r_p                           1654168 non-null  float64
#  63  i_p                           1654168 non-null  float64
#  64  z_p                           1654168 non-null  float64
#  65  elodie_color_index            995834 non-null   float64
#  66  elodie_temperature            995834 non-null   float64
#  67  elodie_metallicity            995834 non-null   float64
# dtypes: float64(20), object(44), string(4)
# memory usage: 858.2+ MB
# None
#
# Top Value Counts:  dr7objid
# 588007006336254064    1
# 587729228224856247    1
# 587725816425349352    1
# 587725816425349338    1
# 587729409682702509    1
# Name: count, dtype: Int64
#
# Top Value Counts:  dr8objid
# 1237651252584448100    1
# 1237651537650188474    1
# 1237655130907213985    1
# 1237655130907213962    1
# 1237651252584317111    1
# Name: count, dtype: Int64
#
# Top Value Counts:  specobjid
# 1105637323304888320    2
# 693725631380219904     1
# 693717659920918528     1
# 693716835287197696     1
# 693716560409290752     1
# Name: count, dtype: Int64
#
# Top Value Counts:  gz2_filenumber
# 192933    1
# 12543     1
# 32613     1
# 32612     1
# 292917    1
# Name: count, dtype: Int64
